# %% [markdown]
# ## Prepare a dataframe from JSON files

# %%
# Define a list to store the extracted data
data = []

# Path to the folder containing JSON documents
folder_path = "./json/articles/"

# Iterate through JSON files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        with open(os.path.join(folder_path, filename), "r") as json_file:
            document = json.load(json_file)
            
            # Extract title, abstract, and body text with error handling
            doc_id = document.get("docId", "")
            title = document["metadata"].get("title", "")
            abstract_data = document.get("abstract", [])
            body_text_items = document.get("body_text", [])
            
            # Initialize abstract as an empty string
            abstract = ""
            
            # Check the type of abstract_data
            if isinstance(abstract_data, list):
                # If it's a list, try to extract the sentences
                try:
                    abstract = " ".join([item["sentence"] for item in abstract_data])
                except (KeyError, TypeError):
                    abstract = ""
            elif isinstance(abstract_data, str):
                # If it's a string, consider it as the entire abstract
                abstract = abstract_data
            
            # Append the extracted data to the list
            data.append({
                "DocID": doc_id,
                "Title": title,
                "Abstract": abstract,
                "BodyText": " ".join([item["sentence"] for item in body_text_items])
            })

# Create a DataFrame from the extracted data
df = pd.DataFrame(data)

# %%
df
# Out:
#                    DocID                                              Title  \
# 0      S0001457513002972  A system of safety management practices and wo...
# 1      S0001457513004806  Network-level accident-mapping: Distance based...
# 2      S0001457514003091  Measuring errors and violations on the road: A...
# 3      S0001457515001098  Operating under the influence: Three year reci...
# 4      S000145751500127X  Real-time driver drowsiness feedback improves ...
# ...                  ...                                                ...
# 40086  S8756328219302856  PYY is a negative regulator of bone mass and s...
# 40087  S8756328219304004  Development of protocols for the first serial ...
# 40088  S8756328219304715  Overexpression of Pitx1 attenuates the senesce...
# 40089  S8756328219304739  The effect of pubertal timing, as reflected by...
# 40090  S8756328219304892  Skeletal effects of plyometric exercise and me...
#
#                                                 Abstract  \
# 0      Objective The overall research objective was t...
# 1      The objective of an accident-mapping algorithm...
# 2      The Driver Behavior Questionnaire (DBQ) is a s...
# 3      Operating a motor vehicle under the influence ...
# 4      Driver drowsiness has been implicated as a maj...
# ...                                                  ...
# 40086  Objective: Bone loss in anorexia nervosa and f...
# 40087  There is an unmet need for a high-resolution t...
# 40088  To explore the role of low expression of Pitx1...
# 40089  Objective: To examine the relationship between...
# 40090  Estrogen deficiency causes bone loss and skele...
#
#                                                 BodyText
# 0      In particular, the individual worker interface...
# 1      The location coordinates of the accident is de...
# 2      Briefly, the Cohort II study randomly sampled ...
# 3      In addition to loss of life, the economic cost...
# 4      However, the effects of feedback on other appr...
# ...                                                  ...
# 40086  Scans were performed at 50 kV, 200 μA, 0.5 mm ...
# 40087  We have generated and compared SBF SEM data fr...
# 40088  However, this process needs to be confirmed. C...
# 40089  In terms of limitations, whereas timing of the...
# 40090  The combined intervention generally improved t...
#
# [40091 rows x 4 columns]

# %% [markdown]
# ### Save csv for easier access later

# %%
df.to_csv("elsevier_corpus.csv", index=False)
